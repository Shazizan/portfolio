# %% [markdown]
# <a href="https://colab.research.google.com/github/Shazizan/portfolio/blob/master/etl_vault_framework_load_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my personal framework for load (L) using GITHUB API into my personal target repo 🔃

# %% [markdown]
# - target: Github repo (pipeline-vault)
# - file format: CSV
# - load method: GITHUB API

# %%
# install pygithub
# !pip install PyGithub

# import libraries
from github import Github, Auth

# create authentication using Auth
auth = Auth.Token("YOUR_GITHUB_TOKEN")

# pass auth object to Github
g = Github(auth=auth)

# access the repo (when repo belongs to your personal GitHub Account).
repo = g.get_user().get_repo("YOUR_REPO_NAME")

# create new file in repo --> csv format (using framework enhancement step 6)
# since I'm using github, the best format is csv format.
file_path = "FILE_NAME_DOT_FORMAT"

  try:
      contents = repo.get_contents(file_path)
      # file exists -> update
      repo.update_file(
           file_path,
           "updated via ETL",
           csv_string,
           contents.sha
      )
  except:
      # file does not exist -> create
      repo.create_file(
           file_path,
           "created via ETL",
           csv_string
      )
